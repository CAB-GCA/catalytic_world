# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('..')  # allow importing from parent directory
from fun_gilles import *
import cmcrameri.cm as cmc

# %%
reactions = read_file("examples/incompatible.txt")
species = obtain_species(reactions)

n_iterations = 100
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1]*6 # len(k)= # de reacciones
# Volume:
V = 1000
initial_food = [1000]*3 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 13
#      10 V = 1000
#      11 initial_food = [1000]*3 # initial molecules number
# ---> 13 abundances, times, V = chemistry(method, n_iterations, reactions,
#      14                                 initial_food, k, V)
#
# File c:\Users\cvzad\Documents\all_obs\master\tfm\catalytic_world\fun_gilles.py:189, in chemistry(method, iterations, reactions, initial_food, k, V, **kwargs)
#     186 abundances[0, :] = initial_food
#     188 if check_thermodynamics(reactions) == False:
# --> 189     raise Exception('El sistema no es compatible termodinámicamente')
#     191 if method == 'Gillespie': # estochastic algorithm
#     192     # TODO cuando funcione protocell con el threshold bien ->
#     193     # - quitar iterations de protocell
#    (...)
#     197     # if iterations is None:
#     198     #     raise Exception("Gillespie method requires the 'iterations' parameter.")
#     200     abundances, times, V = gillespie(abundances, m, k_types, k, c, V, iterations)
#
# Exception: El sistema no es compatible termodinámicamente
