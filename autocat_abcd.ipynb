# %% [markdown]
# # Inicialización

# %%
import numpy as np
import matplotlib.pyplot as plt
from fun_gilles import *

# %%
def plot(abundances, times, V):
    colors = plt.cm.Spectral(np.linspace(0, 1, len(species)))

    # --- Create the figure and a 1-row, 3-column subplot grid ---
    # Using a wide figsize for a horizontal layout.
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5), sharey=False) 
    # Note: sharex=True is removed because we need the x-axis ticks on all three plots, 
    # although they are the same (time).

    # --- Subplot 1 (Left): Concentration ---
    ax1 = axes[0]
    for i in range(len(species)):
        # Calculate Concentration = Abundance / Volume
        ax1.plot(times, abundances[:, i] / V, label=species[i], color=colors[i], alpha=0.9)
    ax1.grid(True, linestyle='--', alpha=0.3)
    ax1.set_xlabel("Time")
    ax1.set_ylabel("Concentration")
    ax1.set_title("Concentration Evolution")

    # --- Subplot 2 (Middle): Volume ---
    ax2 = axes[1]
    ax2.plot(times, V, color='gray')
    ax2.grid(True, linestyle='--', alpha=0.3)
    ax2.set_xlabel("Time")
    ax2.set_ylabel("Volume")
    ax2.set_title("Volume Evolution")


    # --- Subplot 3 (Right): Abundances and Legend ---
    ax3 = axes[2]
    for i in range(len(species)):
        ax3.plot(times, abundances[:, i], label=species[i], color=colors[i], alpha=0.9)
    ax3.grid(True, linestyle='--', alpha=0.3)
    ax3.set_xlabel("Time")
    ax3.set_ylabel("Abundances")
    ax3.set_title("Abundance Evolution")
    # Place the legend here, slightly outside the plot area for all species
    ax3.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), title="Species")


    # --- Final Touches ---
    # Add a figure-wide title
    fig.suptitle(f"Simulation Results (k= {k})", fontsize=16)

    # Adjust layout to prevent labels/titles from overlapping
    plt.tight_layout(rect=[0, 0, 1, 1]) # Adjust tight_layout for a single row

    plt.show()

# %%
file = 'reactions_autocat.txt'
reactions = read_file(file)
species = obtain_species(reactions)

# %% [markdown]
# # Exploración inicial

# %%
n_iterations = 100000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1]*8 # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [1000] + [0]*3 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %% [markdown]
# ## Muere

# %%
n_iterations = 42000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1]*8 # len(k)= # de reacciones
# Volume:
V = 200
initial_food = [100]*4 + [500] + [0]*3 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)
# Out:
# La probabilidad total es 0 !!

# %%
plot(abundances, times, V)

# %%
n_iterations = 50000
method = "Gillespie" # Gillespie or Deterministic
# Reaction constants:
k = [1]*12 # len(k)= # de reacciones
# Volume:
V = 200
initial_food = [100]*4 + [500] + [0]*3 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

# %%
plot(abundances, times, V)

# %% [markdown]
# ### si cambio el vol

# %%
n_iterations = 100000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1]*8 # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [1000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)
# Out:
# La probabilidad total es 0 !!

# %% [markdown]
# ### algunas irreversibles para encontrar las que fastidian

# %%
# este va perfe
n_iterations = 10000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1,0]*4 # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [1000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %%
# este va bien
n_iterations = 50000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1]*2+[1,0]*3 # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [10000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %%
# este va bien
n_iterations = 50000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1,1,1,0,1,1,1,0] # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [10000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %%
# este va bien pero le fastidia un poco más
n_iterations = 50000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1,0,1,1,1,0,1,1] # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [10000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %%
# este va bien, pero se queda estacionario en un volumen a partir del cual no crece
n_iterations = 100000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1,0,1,1,1,1,1,1] # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [10]*4 + [50000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)

# %% [markdown]
# # Irreversibles

# %%
n_iterations = 10000
method = "Protocell" # Gillespie or Deterministic
# Reaction constants:
k = [1,0]*4 # len(k)= # de reacciones
# Volume:
V = 2000
initial_food = [1000]*4 + [1000]*2 + [0]*2 # initial molecules number

abundances, times, V = chemistry(method, n_iterations, reactions,
                                initial_food, k, V)

plot(abundances, times, V)
